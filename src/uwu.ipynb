# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns

# %%
columns = ["id", "Daerah", "SumbuUtama", "SumbuKecil", "Keunikan", "AreaBulatan", "Diameter", "KadarAir", "Keliling", "Bulatan", "Ransum", "Kelas"]
df = pd.read_csv("Gandum.csv", header = None, names = columns).set_index("id")

# %%
#Nomor 2
bxplt_daerah = df.boxplot(column=["Daerah"])
hist_daerah = df.hist(column=["Daerah"])

# %%
bxplt_su = df.boxplot(column=["SumbuUtama"])
hist_su = df.hist(column=["SumbuUtama"])

# %%
bxplt_sk = df.boxplot(column=["SumbuKecil"])
hist_sk = df.hist(column=["SumbuKecil"])

# %%
bxplt_unik = df.boxplot(column=["Keunikan"])
hist_unik = df.hist(column=["Keunikan"])

# %%
bxplt_area = df.boxplot(column=["AreaBulatan"])
hist_area = df.hist(column=["AreaBulatan"])

# %%
bxplt_diameter = df.boxplot(column=["Diameter"])
hist_diameter = df.hist(column=["Diameter"])

# %%
bxplt_kadar = df.boxplot(column=["KadarAir"])
hist_kadar = df.hist(column=["KadarAir"])

# %%
bxplt_keliling = df.boxplot(column=["Keliling"])
hist_keliling = df.hist(column=["Keliling"])

# %%
bxplt_bulatan = df.boxplot(column=["Bulatan"])
hist_bulatan = df.hist(column=["Bulatan"])

# %%
bxplt_ransum = df.boxplot(column=["Ransum"])
hist_ransum = df.hist(column=["Ransum"])

# %%
df.corr()
# Out:
#                Daerah  SumbuUtama  SumbuKecil  Keunikan  AreaBulatan  \
# Daerah       1.000000    0.900374    0.807427  0.623023     0.997242
# SumbuUtama   0.900374    1.000000    0.580837  0.759118     0.902007
# SumbuKecil   0.807427    0.580837    1.000000  0.078605     0.806536
# Keunikan     0.623023    0.759118    0.078605  1.000000     0.625055
# AreaBulatan  0.997242    0.902007    0.806536  0.625055     1.000000
# Diameter     0.997963    0.903146    0.804706  0.636689     0.994744
# KadarAir    -0.110243   -0.135363   -0.027475 -0.159963    -0.124494
# Keliling     0.881662    0.850753    0.657753  0.660141     0.911196
# Bulatan     -0.389929   -0.499682   -0.105894 -0.563362    -0.447149
# Ransum       0.662482    0.792583    0.106648  0.968624     0.664747
# Kelas       -0.602747   -0.713091   -0.152975 -0.730456    -0.607313
#
#              Diameter  KadarAir  Keliling   Bulatan    Ransum     Kelas
# ...

# %%
# Nomor 6
df[df.columns[0:]].corr()["Kelas"][:-1]
# Out:
# Daerah        -0.602747
# SumbuUtama    -0.713091
# SumbuKecil    -0.152975
# Keunikan      -0.730456
# AreaBulatan   -0.607313
# Diameter      -0.602536
# KadarAir       0.134344
# Keliling      -0.634861
# Bulatan        0.545005
# Ransum        -0.839904
# Name: Kelas, dtype: float64
